# %% [markdown]
# ## Programavimo įvado pratybos - 3 savaitė
#
# Dirbame **poromis**: vienas rašo, kitas seka ir klausia „kodėl?“. Po kas antros užduoties keičiatės vietomis.
#
# **A dalis - privaloma.** Ji tiesiogiai remiasi šios savaitės paskaita; ją turite atlikti visi.
# **B dalis - papildoma.** Smalsiesiems arba jei liko laiko.
#
# > **Pratybų pabaigoje atliktas užduotis nepamirškite įkelti į emokymai.vu.lt**
# `File → Download → .ipynb` arba `.py` su savo atsakymais.
#
# ---
#
# - Python komandoms prisiminti: `https://www.w3schools.com/python/`
# - Komentaras kode: `#` - viską po jo Python ignoruoja
# - Šios savaitės įrankiai vienoje vietoje:
#
#     - `type(x)` - kokios rūšies yra vertė
#     - `int(x)` · `float(x)` · `str(x)` - rūšies keitimas
#     - `s[3]` · `s[2:6]` · `s[-1]` - indeksavimas ir karpymas
#     - `len(s)` · `s.split()` · `s.replace(a, b)` · `s.strip()` · `s.upper()`
#     - `f"T = {t:.2f} s"` - f-eilutė
#     - `sarasas.append(x)` · `sarasas.copy()` · `sum()` · `min()` · `max()`
#
# Prie kiekvienos užduoties parašyta, ką turėtumėte pamatyti - **pasitikrinkite patys**, nelaukdami dėstytojo.

# %% [markdown]
# Visi duomenys Python programavimo kalboje yra objektai. Tai reiškia, kad visi jie yra aprašomi tam tikromis taisyklėmis, kurios nustato ką su tais objektais galima veikti. Ne viską ką galima atlikti su skaičiais, galima atlikti su žodžiais ir atvirkščiai. Pavyzdžiui tam tikro teksto raides galima paversti didžiosiomis `"septyni".upper()`, tačiau to nepavyks padaryti su skaičiumi `7.upper()`.

# %%
# Kintamojo tipą galima patikrinti su funkcija type()
x = "vardas"
y = x
z = 7
w = 12.3

print (type(x))
print (type(y))
print (type(z))
print (type(w))

# %% [markdown]
# Pakeiskite aukščiau esančiame pavyzdyje `z` kintamąjį į `float` tipo ir pakeiskite `w` kintamąjį į `string` tipo.

# %% [markdown]
# Kintamuosius galime konvertuoti tarp skirtingų tipų pasinaudodami funkcijomis `int()`, `float()` ir `str()`.

# %%
skaicius = 123
tekstas = str(skaicius)
skaicius_2 = float(tekstas)

print (type(skaicius))
print (type(tekstas))
print (type(skaicius_2))

# %% [markdown]
# Tekstas (string) yra sudėtinis objektas - sudarytas iš atskirų simbolių. Juos galima indeksuoti.

# %%
tekstas = "Treciosios programavimo pratybos 2026 metais"

pirma_raide = tekstas[0]

print (pirma_raide)

# Galima pasirinkti ir daugiau nei vieną simbolį panaudojant indeksavimą

pirmas_zodis = tekstas[0:10]

print (pirmas_zodis)

# %% [markdown]
# Modifikuokite viršuje esantį kodą, kad iškirptumėte "2026". Konvertuokite į skaičių, ir padalinkite iš 5.

# %% [markdown]
# Sąrašas taip pat yra objektas. Teksto simbolius galime paprastai konvertuoti į sąrašą su funkcija `list()`. Ši funkcija kiekvieną teksto simbolį paverčia atskiru sąrašo nariu. Jeigu norime atskirti ties tam tikrais simboliais, galime naudoti `string.split()` - kur string yra kažkoks tekstas.

# %%
tekstas = "To the mind that is still, the whole universe surrenders."

sarasas = list(tekstas)
sarasas2 = tekstas.split(",")   # Tekstą į atskirtas dalis atskiriame ties kableliu
print (sarasas2)

# %% [markdown]
# Modifikuokite viršuje esantį kodą taip, kad sąraše atsidurtų atskiri žodžiai. Tam jums reikės atlikti du veiksmus. Pirmiausia tekste panaikinti kablelį su `string.replace()` metodu, ir tuomet pasinaudojant `string.split()` atskirti ties tarpais (spaces).

# %% [markdown]
# Sąrašas taip pat yra sudėtinis objektas (sudarytas iš narių), tad galime juos indeksuoti. Žemiau esančiame kodo pavyzdyje, atskiriame sakinį ties kableliu, vadinasi turime du narius (iki ir po kablelio), ir indeksuodami apsirenkame pirmąją sakinio dalį su indeksu `[0]` - programavime pirmasis narys lygus 0.

# %%
tekstas = "To the mind that is still, the whole universe surrenders."

sarasas = tekstas.split(",")

print (sarasas[0])

# %% [markdown]
# Modifikuokite aukščiau esantį kodą taip, kad pasirinktumėte pirmą, antrą, trečią, septintą, aštuntą ir devintą žodžius.

# %% [markdown]
# ## A užduotis - privaloma dalis
#
# **Nuo duomenų eilutės iki ataskaitos.** A1 - apšilimas. Nuo A2 iki A10 kiekviena užduotis remiasi ankstesne, todėl **langelius paleidinėkite iš eilės, iš viršaus žemyn**.
#
# Tai lygiai tas pats kelias, kurį paskaitoje nuėjome per demonstraciją: išpjauti → paversti skaičiais → suskaičiuoti → gražiai atspausdinti → ir nesugadinti duomenų.

# %% [markdown]
# #### A1 - Apšilimas: vardas iš abėcėlės
#
# Jums sukurtas kintamasis `letters`. Pasinaudodami **tik indeksavimu**, surinkite savo vardą ir atspausdinkite jį iš didžiosios raidės.
#
# Užuomina: indeksuojama laužtiniais skliaustais, `letters[5]` grąžina `f`. Tekstus sujungti galima pliusu: `letters[0] + letters[13]`. Didžiąją raidę padarys `.upper()`.
#
# *Pavyzdys - vardui Ana:* `letters[0].upper() + letters[13] + letters[0]`
#
# *Turi pasirodyti:* `Ana`

# %%
letters = "abcdefghijklmnopqrstuvwxyz"

# %% [markdown]
# ---
# ### Tikra spektroskopijos programos išvestis
#
# Žemiau esanti eilutė - **tikra** žvaigždės spektro analizės programos antraštė. Būtent ją paskaitoje matėte gyvai.
#
# Duomenų failai beveik visada standartizuoti: kartą parašytas kodas, kuris iškerpa reikiamas vertes, veiks ir su kitais tos pačios programos failais. Būtent todėl verta išmokti karpyti.

# %% [markdown]
# #### A2 - Vienas pjūvis
#
# Paleiskite žemiau esantį langelį. `Rv` išpjauta už jus.
#
# Atsakykite komentare po kodu: **kokio tipo** yra `Rv`? Patikrinkite su `type()`, o ne spėkite.
#
# *Turi pasirodyti:* `-55.423 ` ir `<class 'str'>`
#
# Atkreipkite dėmesį į tarpą pabaigoje - išpjovus gaunamas TEKSTAS, o ne skaičius.

# %%
eilute = "Radial velocity =   -55.423  dispersion =   0.902  FWHM =  12.129, 912 lines matched out of 5014"

Rv = eilute[20:28]

print(Rv)
print(type(Rv))

# %% [markdown]
# #### A3 - Likusios keturios vertės
#
# Tokiu pačiu būdu "išpjaukite" dar keturias vertes ir priskirkite jas kintamiesiems:
#
# | kintamasis | ką imame |
# |---|---|
# | `Dis` | dispersion |
# | `FWHM` | FWHM |
# | `matched` | kiek linijų rasta |
# | `total` | iš kiek iš viso |
#
# Užuomina: indeksus rasti lengviausia bandant. Pradėkite nuo `print(eilute[40:50])` ir stumdykite skaičius, kol pataikysite. Tarpai aplink vertę netrukdys - `float()` juos ignoruoja.
#
# Atspausdinkite visas penkias.
#
# *Turi pasirodyti penkios eilutės, kuriose matomi:* `-55.423`, `0.902`, `12.129`, `912`, `5014`

# %% [markdown]
# #### A4 - Iš teksto į skaičius
#
# Paverskite penkias vertes skaičiais: `Rv`, `Dis` ir `FWHM` - `float()`, o `matched` ir `total` - `int()` (tai sveikieji kiekiai, ne matavimai).
#
# Kad nesupainiotumėte, naujiems kintamiesiems duokite kitus vardus, pvz. `Rv_sk`, `Dis_sk`, `FWHM_sk`, `matched_sk`, `total_sk`.
#
# Tada apskaičiuokite ir atspausdinkite santykį `FWHM / dispersion`.
#
# *Turi pasirodyti:* `13.446784922394677`
#
# Jei gavote `TypeError` - vadinasi, dalijate tekstus. Grįžkite prie `float()`.

# %% [markdown]
# #### A5 - Kiek procentų linijų rasta
#
# Apskaičiuokite, kiek procentų visų linijų buvo rasta (`matched` iš `total`), ir atspausdinkite **dviejų skaitmenų po kablelio** tikslumu su procento ženklu.
#
# Naudokite f-eilutę: `f"{x:.2f} %"`.
#
# *Turi pasirodyti:* `18.19 %`
#
# Jei gavote `0.18` - padauginkite iš 100. Jei gavote `0` - vadinasi, dalijate sveikuosius su `//`.

# %% [markdown]
# #### A6 - Ataskaita, kurią pasirašytų vadovas
#
# Atspausdinkite tris vertes **stulpeliu, su lygiuotais kableliais**, po 3 skaitmenis po kablelio. Naudokite plotį: `f"{x:8.3f}"`.
#
# *Turi pasirodyti tiksliai taip:*
# ```
# Radial velocity:  -55.423 km/s
# Dispersion:         0.902 km/s
# FWHM:              12.129 km/s
# ```
#
# Atkreipkite dėmesį, kaip plotis 8 sulygiuoja skaičius nepaisant to, kad vienas jų neigiamas.

# %% [markdown]
# #### A7 - Vertė ± neapibrėžtis
#
# Turite švytuoklės matavimų vidurkį ir neapibrėžtį:
#
# ```python
# vidurkis = 2.0466666666666666
# neapibreztis = 0.032145
# ```
#
# Atspausdinkite juos viena eilute, **abu po 3 skaitmenis po kablelio**.
#
# Ženklą ± galite tiesiog nukopijuoti iš čia.
#
# *Turi pasirodyti:* `T = 2.047 ± 0.032 s`

# %% [markdown]
# #### A8 - Niuansai, apie kuriuos paskaitoje kalbėjome
#
# Turite matavimų sąrašą su akivaizdžiu broku ir „atsarginę kopiją“:
#
# ```python
# matavimai = [2.05, 1.98, 2.11, 87.4]
# kopija = matavimai
# ```
#
# „Išvalykite“ duomenis - pašalinkite `87.4` iš `matavimai` metodu `remove()`. Tada atspausdinkite **abu** sąrašus.
#
# *Turi pasirodyti du vienodi sąrašai:* `[2.05, 1.98, 2.11]` ir `[2.05, 1.98, 2.11]`
#
# Jokios klaidos. Jokio įspėjimo. Atsarginė kopija sugadinta tyliai.
#
# Komentaru prie kodo, vienu sakiniu parašykite, kas ką tik nutiko.

# %% [markdown]
# #### A9 - Pataisykite
#
# Pakartokite A8, bet kopiją pasidarykite **teisingai**: `matavimai.copy()` arba `matavimai[:]`.
#
# Įrodykite spausdindami, kad originali kopija liko nepaliesta.
#
# *Turi pasirodyti:* `[2.05, 1.98, 2.11]` ir `[2.05, 1.98, 2.11, 87.4]`

# %% [markdown]
# #### A10 - Visa ataskaita viename langelyje
#
# Viena tvarkinga struktūra: **duomenys / skaičiavimai / rezultatai**.
#
# - pradėkite nuo `matavimai = [2.05, 1.98, 2.11, 87.4]`,
# - pasidarykite teisingą kopiją ir iš jos pašalinkite broką,
# - apskaičiuokite vidurkį (`sum()/len()`) ir sklaidą (`max() - min()`),
# - atspausdinkite abu f-eilutėmis, po 3 skaitmenis po kablelio, su vienetais.
#
# *Turi pasirodyti:*
# ```
# vidurkis = 2.047 s
# sklaida  = 0.130 s
# ```
#
# Patikra kaip fizikų: laikinai įrašę visus matavimus po `2.0`, privalote gauti vidurkį `2.000` ir sklaidą `0.000`. Jei negaunate - klaida formulėje, ne duomenyse.

# %% [markdown]
# ---
# ### A dalis baigta
#
# > **Pratybų pabaigoje atliktas užduotis nepamirškite įkelti į emokymai.vu.lt**

# %% [markdown]
# ## B užduotis - papildoma dalis
#
# Kam liko laiko arba kam įdomu. Šios užduotys nesiremia viena kita - imkite, kuri patinka.

# %% [markdown]
# #### B1 - Auditorijos numeris
#
# Sukurkite kintamąjį `auditorija` ir priskirkite jam savo auditorijos numerį pasinaudodami **tik** kintamuoju `digits`.
#
# Užuomina: `digits` yra skaičius, o indeksuoti galima tik tekstą. Pirmiausia `str()`.
#
# *Pavyzdys - auditorijai 806:* `str(digits)[7] + str(digits)[9] + str(digits)[5]`
#
# *Turi pasirodyti:* `806`

# %%
digits = 1234567890

# %% [markdown]
# #### B2 - Dalyba su liekana
#
# Padalinkite B1 sukurtą `auditorija` iš `sakinys` ilgio (simbolių skaičiaus) ir atspausdinkite tokį raportą:
#
# ```
# Auditorijos numeris: 806
# Sakinio ilgis: 106
# 806 // 106 = 7 (liekana 64)
# ```
#
# Užuomina: `//` yra sveikoji dalyba (kiek kartų telpa), `%` - liekana. Nepamirškite `int()`.
#
# *Turi pasirodyti (auditorijai 806):* `806 // 106 = 7 (liekana 64)`

# %%
sakinys = "Kai programuotojas susiduria su sunkumais ieškodamas klaidų, tai reiškia, kad jis ieško ne ten kur reikia."

# %% [markdown]
# #### B3 - Pakeitimai
#
# Pasinaudokite B2 kintamuoju `sakinys`. Pakeiskite visas `s` raides skaičiumi `5` ir visas raides padarykite didžiosiomis.
#
# *Turi prasidėti:* `KAI PROGRAMUOTOJA5 5U5IDURIA 5U 5UNKUMAI5 ...`
#
# Atkreipkite dėmesį į eilės tvarką: jei pirma padarysite didžiąsias, mažųjų `s` nebeliks. Išbandykite abu variantus.

# %% [markdown]
# #### B4 - Žodžio ilgis
#
# Parašykite kodą, kuris paprašytų įvesti žodį, ir atspausdintų: `Jūs įvedėte žodį "spektras", kurio ilgis yra 8.`
#
# Užuomina: `input()`, `len()`, f-eilutė.

# %% [markdown]
# #### B5 - Veidrodinis skaičius
#
# Paprašykite įvesti bet kokį natūralųjį skaičių, tada padalinkite jį iš jo veidrodinės versijos (457 → 754).
#
# Užuomina: apsukti tekstą galima karpymo žingsniu `[::-1]`.
#
# *Turi pasirodyti (įvedus 457):* `457 / 754 = 0.606`

# %% [markdown]
# #### B6 - Sąrašo statistika
#
# Sukurkite sąrašą `numbers` iš šios dienos datos skaitmenų (pvz. 2026 09 17 → `[2, 0, 2, 6, 0, 9, 1, 7]`).
#
# - išrikiuokite jį didėjimo tvarka,
# - raskite didžiausią, mažiausią ir vidurkį.
#
# Užuomina: `sorted(numbers)` grąžina **naują** sąrašą, o `numbers.sort()` rikiuoja vietoje ir grąžina `None`. Išbandykite `x = numbers.sort()` ir atspausdinkite `x` - pamatysite savo akimis.

# %% [markdown]
# #### B7 - Šifras
#
# Klasika. Turite abėcėlę ir sumaišytą jos versiją:
#
# ```python
# letters = "abcdefghijklmnopqrstuvwxyz "
# code    = "zxfdbhtja epqucovgwlsykmnir"
# ```
#
# Kiekviena `letters` raidė keičiama ta pačia vieta stovinčia `code` raide: `a` → `z`, `b` → `x`, `c` → `f` ir taip toliau.
#
# Atkoduokite žinutę:
#
# ```python
# message = "zlb zsrozqzfazsrustzpb zs"
# ```
#
# Užuominos: `letters.index("x")` grąžina raidės vietą. Šiai užduočiai prireiks **ciklo** - tai 4 savaitės tema, todėl čia ji papildoma: `https://www.w3schools.com/python/python_for_loops.asp`
#
# *Turi pasirodyti:* `atejau pamaciau nugalejau`

# %%
letters = "abcdefghijklmnopqrstuvwxyz "
code    = "zxfdbhtja epqucovgwlsykmnir"
message = "zlb zsrozqzfazsrustzpb zs"

# %% [markdown]
# #### B8 - Sąrašai sąrašuose
#
# Sukurkite `lentele = [[1, 2], [3, 4]]` ir jos kopiją su `.copy()`. Pakeiskite `lentele[0][0] = 99` ir atspausdinkite kopiją.
#
# *Turi pasirodyti:* `[[99, 2], [3, 4]]`
#
# Kodėl? `.copy()` nukopijavo tik **išorines** rodykles; vidinės eilutės liko bendros. Tai vadinama sekliąja kopija. 10 savaitę numpy šią problemą išspręs už jus.

# %% [markdown]
# ## Sandbox
