# %% [markdown]
# <a href="https://colab.research.google.com/github/DrArnas/2026_seminars/blob/main/Python_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Programavimo įvado pratybos - 1
#
# **Pirmasis kontaktas.** Šiandien: pirmosios Python komandos, pirmieji kintamieji - ir visos trys klaidų rūšys iš paskaitos.
#
# Darbo aplinka - Google Colab:
#
# - Atsidarykite pateiktą laboratorinio failo nuorodą: viršuje spauskite `File` ir `Save a copy in Drive`.
# - Kodo langelis (cell) vykdomas su **Shift+Enter** arba ▷ mygtuku.
# - Python komandoms prisiminti: `https://www.w3schools.com/python/`
# - Komentarai: `#`
#
# Dirbame porose: vienas rašo, kitas diktuoja ir tikrina. Keičiamės kas dvi užduotis.

# %% [markdown]
# Rezultato atvaizdavimui naudojame funkciją `print()`
#
# `print ("Fizika veikia")`

# %% [markdown]
# Pakeiskite viršuje esantį kodą, atspausdinti bet kokiam kitam sakiniui.

# %% [markdown]
# Dabar kodą **sugadinkite tyčia**: ištrinkite paskutines kabutes ir paleiskite langelį.
#
# Perskaitykite pranešimą apačioje - kurioje vietoje Python „pasidavė“? Prisiminkite paskaitą: kuri tai klaidų rūšis - sintaksės, vykdymo (runtime) ar logikos?

# %% [markdown]
# Aritmetika rašoma tiesiai į `print()`. Prieš paleisdami langelį - **porose nuspėkite**, ką atspausdins kiekviena eilutė.
#
# `print (7 + 3 * 2)`
#
# `print ((7 + 3) * 2)`

# %% [markdown]
# Kokia taisyklė lėmė pirmos eilutės rezultatą? (Ta pati, kaip matematikoje - veiksmų eiliškumas.)

# %% [markdown]
# ## A užduotis
#
# Matavome švytuoklės periodą su chronometru - tris kartus, sekundėmis.

# %% [markdown]
# #### A1
#
# Sukurkite tris kintamuosius ir priskirkite jiems matavimų vertes:
#
# `t1 = 2.05`, `t2 = 1.98`, `t3 = 2.11`
#
# Paleiskite langelį. Pastaba: jokio rezultato ekrane **nėra ir neturi būti** - priskyrimas nieko nespausdina.

# %% [markdown]
# #### A2
#
# Atspausdinkite `t1` vertę. Tada pabandykite atspausdinti `T1` (didžiąja raide).
#
# Perskaitykite klaidos pranešimą: kaip ji vadinasi ir kuri tai klaidų rūšis?

# %% [markdown]
# #### A3
#
# Suskaičiuokite matavimų vidurkį „akivaizdžiu” būdu - **būtent taip, kaip parašyta**:
#
# `vidurkis = t1 + t2 + t3 / 3`
#
# Atspausdinkite rezultatą. Patikrinkite kaip fizikai: visi trys matavimai ≈ 2 s, tai ir vidurkis privalo būti ≈ 2 s. Ar taip ir yra?

# %% [markdown]
# #### A4
#
# Programa suveikė be jokio klaidos pranešimo - ir vis tiek **pamelavo**. Kuri tai klaidų rūšis?
#
# Pataisykite formulę skliaustais, kad vidurkis būtų teisingas, ir vėl patikrinkite: ar rezultatas tarp mažiausio ir didžiausio matavimo?

# %% [markdown]
# #### A5
#
# Padarykite išvestį gražią: atspausdinkite sakinį su tekstu ir verte, pvz. `Vidutinis periodas: 2.05 s`.
#
# Hint: skaičių suapvalinti galima funkcija `round(vidurkis, 2)` - antras argumentas nurodo skaitmenų kiekį po kablelio. `print()` viduje galima rašyti kelis dalykus, atskirtus kableliais.

# %% [markdown]
# #### A6
#
# Laboratorija eksperimentą pakartojo. Nauji duomenys: `t1 = 2.02`, `t2 = 2.09`, `t3 = 1.95`.
#
# Pakeiskite **tik** A1 langelio duomenis ir iš eilės paleiskite žemiau esančius langelius iš naujo. Formulės nelieskite!
#
# Taisyklė, kurią čia atradote: **duomenys atskirai nuo logikos** - pakeitus duomenis, programa lieka ta pati.

# %% [markdown]
# #### A7
#
# Chronometras sugedo: ketvirtas matavimas `t4 = 0`.
#
# Pridėkite jį, išplėskite vidurkį iki keturių verčių, ir papildomai suskaičiuokite santykinę sklaidą:
#
# `sklaida = (max(t1, t2, t3, t4) - min(t1, t2, t3, t4)) / min(t1, t2, t3, t4)`
#
# Kas atsitiko ir kodėl? Kuri tai klaidų rūšis? Po eksperimento `t4` ištrinkite ir grąžinkite vidurkį į tris vertes.

# %% [markdown]
# ## B užduotis
#
# Sudėkite viską į **vieną tvarkingą langelį** - pilną veikiančią programą nuo nulio, tokia struktūra:
#
# ```
# # Švytuoklės eksperimentas, grupė ...
# # duomenys
# ...
# # skaičiavimai
# ...
# # rezultatai
# ...
# ```

# %% [markdown]
# #### B1
#
# Programa turi atspausdinti tris eilutes:
#
# - visus tris matavimus su vienetais,
# - vidutinį periodą (3 skaitmenys po kablelio),
# - santykinę sklaidą (3 skaitmenys po kablelio).
#
# Patikrinkite programą su „žinomu atsakymu“: laikinai įrašykite visus matavimus po `2.0` - vidurkis privalo būti lygiai `2.0`, o sklaida `0.0`. Jei ne - programa meluoja. Patikrinę, grąžinkite tikrus duomenis.

# %% [markdown]
# ## Papildomos užduotys (norintiems daugiau)
#
# #### S1
#
# Idealios švytuoklės periodas $T = 2\pi\sqrt{L/g}$. Žinodami vidutinį periodą iš B1 ir $g = 9.81$, apskaičiuokite švytuoklės ilgį $L$ ir atspausdinkite centimetrais.
#
# Hint: šaknis Python kalboje - kėlimas laipsniu `0.5`, t. y. `x ** 0.5`; $\pi$ vertę kol kas įsirašykite ranka: `pi = 3.14159`.
#
# #### S2
#
# Python turi paruoštų įrankių: `import statistics`, tada `statistics.mean([t1, t2, t3])`. Palyginkite su savo B1 rezultatu. (Laužtiniai skliaustai - sąrašas; apie juos visą paskaitą kalbėsime 3 savaitę.)
#
# #### S3
#
# Perrašykite B1 taip, kad matavimus įvestų naudotojas klaviatūra. Pasidomėkite funkcijomis `input()` ir `float()` - jų dar nesimokėme, bet `https://www.w3schools.com/python/` viskas aprašyta.

# %% [markdown]
# ## Sandbox
